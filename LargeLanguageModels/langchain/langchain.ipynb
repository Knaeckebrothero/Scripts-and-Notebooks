# %%
"""
https://www.youtube.com/watch?v=aywZrzNaKjs
"""
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

# %%
from langchain.llms import OpenAI
llm = OpenAI(model_name='text-davinci-003')
llm("Hello can you read this?")
# Out:
# '\n\nYes, I can read this.'

# %%
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI

llm = OpenAI(model_name='text-davinci-003', temperature=0.5)
chat = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5) # "gpt-4" "gpt-3.5-turbo"

messages = [
    SystemMessage(content="You are a assistant and your name is Peter."),
    #HumanMessage(content="Hi, who are you and what is your name?")
]

# modle_name="gpt-3.5-turbo", temprature=0.5
print(llm.predict("Hi what is your name?"))
print(chat.predict("Hi what is your name?"))
# Out:
# My name is ____.
# Hello! I am an AI language model developed by OpenAI, and I am known as GPT-3. How can I assist you today?
